# %%
# !wget --no-check-certificate \
https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
-O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2023-02-23 07:06:23--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.24.128, 142.250.4.128, 142.251.10.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.24.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M  20.9MB/s    in 3.8s
#
# 2023-02-23 07:06:27 (17.2 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %%
# 기본 경로
base_dir = '/tmp/cats_and_dogs_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# 훈련에 사용되는 고양이/개 이미지 경로
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')
print(train_cats_dir)
print(train_dogs_dir)

# 테스트에 사용되는 고양이/개 이미지 경로
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')
print(validation_cats_dir)
print(validation_dogs_dir)
# Out:
# /tmp/cats_and_dogs_filtered/train/cats
# /tmp/cats_and_dogs_filtered/train/dogs
# /tmp/cats_and_dogs_filtered/validation/cats
# /tmp/cats_and_dogs_filtered/validation/dogs

# %%
train_cat_fnames = os.listdir( train_cats_dir )
train_dog_fnames = os.listdir( train_dogs_dir )

print(train_cat_fnames[:5])
print(train_dog_fnames[:5])
# Out:
# ['cat.981.jpg', 'cat.189.jpg', 'cat.322.jpg', 'cat.316.jpg', 'cat.918.jpg']
# ['dog.645.jpg', 'dog.75.jpg', 'dog.865.jpg', 'dog.680.jpg', 'dog.780.jpg']

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows, ncols = 4, 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index+=8

next_cat_pix = [os.path.join(train_cats_dir, fname)
                for fname in train_cat_fnames[ pic_index-8:pic_index]]

next_dog_pix = [os.path.join(train_dogs_dir, fname)
                for fname in train_dog_fnames[ pic_index-8:pic_index]]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import tensorflow as tf


model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(lr=0.001),
            loss='binary_crossentropy',
            metrics = ['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

train_generator = train_datagen.flow_from_directory(train_dir,
                                                  batch_size=20,
                                                  class_mode='binary',
                                                  target_size=(150, 150))
validation_generator =  test_datagen.flow_from_directory(validation_dir,
                                                       batch_size=20,
                                                       class_mode  = 'binary',
                                                       target_size = (150, 150))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=100,
                    epochs=100,
                    validation_steps=50,
                    verbose=2)
# Out:
# Epoch 1/100
# 100/100 - 22s - loss: 0.6861 - accuracy: 0.5685 - val_loss: 0.6995 - val_accuracy: 0.5650 - 22s/epoch - 221ms/step
# Epoch 2/100
# 100/100 - 10s - loss: 0.6197 - accuracy: 0.6615 - val_loss: 0.6143 - val_accuracy: 0.6460 - 10s/epoch - 98ms/step
# Epoch 3/100
# 100/100 - 10s - loss: 0.5662 - accuracy: 0.7095 - val_loss: 0.5891 - val_accuracy: 0.6950 - 10s/epoch - 98ms/step
# Epoch 4/100
# 100/100 - 11s - loss: 0.5257 - accuracy: 0.7445 - val_loss: 0.5576 - val_accuracy: 0.7090 - 11s/epoch - 111ms/step
# Epoch 5/100
# 100/100 - 9s - loss: 0.4888 - accuracy: 0.7595 - val_loss: 0.5550 - val_accuracy: 0.7310 - 9s/epoch - 87ms/step
# Epoch 6/100
# 100/100 - 10s - loss: 0.4404 - accuracy: 0.7865 - val_loss: 0.6336 - val_accuracy: 0.6470 - 10s/epoch - 96ms/step
# Epoch 7/100
# 100/100 - 10s - loss: 0.3831 - accuracy: 0.8265 - val_loss: 0.6259 - val_accuracy: 0.7020 - 10s/epoch - 97ms/step
# Epoch 8/100
# 100/100 - 10s - loss: 0.3209 - accuracy: 0.8590 - val_loss: 0.6285 - val_accuracy: 0.7190 - 10s/epoch - 96ms/step
# Epoch 9/100
# 100/100 - 9s - loss: 0.2677 - accuracy: 0.8820 - val_loss: 0.5793 - val_accuracy: 0.7360 - 9s/epoch - 87ms/step
# Epoch 10/100
# 100/100 - 9s - loss: 0.1918 - accuracy: 0.9240 - val_loss: 0.7674 - val_accuracy: 0.7030 - 9s/epoch - 95ms/step
# Epoch 11/100
# 100/100 - 10s - loss: 0.1335 - accuracy: 0.9485 - val_loss: 0.8031 - val_accuracy: 0.7220 - 10s/epoch - 97ms/step
# Epoch 12/100
# 100/100 - 10s - loss: 0.0874 - accuracy: 0.9695 - val_loss: 0.9671 - val_accuracy: 0.7150 - 10s/epoch - 97ms/step
# Epoch 13/100
# 100/100 - 9s - loss: 0.0693 - accuracy: 0.9835 - val_loss: 1.0521 - val_accuracy: 0.7340 - 9s/epoch - 87ms/step
# Epoch 14/100
# 100/100 - 10s - loss: 0.0417 - accuracy: 0.9890 - val_loss: 1.2335 - val_accuracy: 0.7420 - 10s/epoch - 95ms/step
# Epoch 15/100
# 100/100 - 10s - loss: 0.0536 - accuracy: 0.9890 - val_loss: 2.0065 - val_accuracy: 0.6800 - 10s/epoch - 96ms/step
# Epoch 16/100
# 100/100 - 10s - loss: 0.0355 - accuracy: 0.9880 - val_loss: 1.4161 - val_accuracy: 0.7440 - 10s/epoch - 97ms/step
# Epoch 17/100
# 100/100 - 11s - loss: 0.1633 - accuracy: 0.9880 - val_loss: 1.4372 - val_accuracy: 0.7430 - 11s/epoch - 110ms/step
# Epoch 18/100
# 100/100 - 9s - loss: 0.0694 - accuracy: 0.9875 - val_loss: 1.3559 - val_accuracy: 0.7510 - 9s/epoch - 88ms/step
# Epoch 19/100
# 100/100 - 10s - loss: 0.0958 - accuracy: 0.9865 - val_loss: 1.4493 - val_accuracy: 0.7390 - 10s/epoch - 97ms/step
# Epoch 20/100
# 100/100 - 10s - loss: 0.0146 - accuracy: 0.9950 - val_loss: 1.4504 - val_accuracy: 0.7400 - 10s/epoch - 98ms/step
# Epoch 21/100
# 100/100 - 10s - loss: 0.0587 - accuracy: 0.9895 - val_loss: 1.4611 - val_accuracy: 0.7280 - 10s/epoch - 98ms/step
# Epoch 22/100
# 100/100 - 9s - loss: 0.0328 - accuracy: 0.9885 - val_loss: 1.7753 - val_accuracy: 0.7050 - 9s/epoch - 88ms/step
# Epoch 23/100
# 100/100 - 12s - loss: 0.0189 - accuracy: 0.9940 - val_loss: 1.6675 - val_accuracy: 0.7440 - 12s/epoch - 121ms/step
# Epoch 24/100
# 100/100 - 10s - loss: 0.0232 - accuracy: 0.9940 - val_loss: 1.9621 - val_accuracy: 0.7240 - 10s/epoch - 96ms/step
# Epoch 25/100
# 100/100 - 10s - loss: 0.0121 - accuracy: 0.9960 - val_loss: 1.7998 - val_accuracy: 0.7370 - 10s/epoch - 98ms/step
# Epoch 26/100
# 100/100 - 10s - loss: 0.0158 - accuracy: 0.9950 - val_loss: 1.7314 - val_accuracy: 0.7430 - 10s/epoch - 97ms/step
# Epoch 27/100
# 100/100 - 9s - loss: 0.0126 - accuracy: 0.9975 - val_loss: 1.7246 - val_accuracy: 0.7340 - 9s/epoch - 88ms/step
# Epoch 28/100
# 100/100 - 9s - loss: 1.7224e-04 - accuracy: 1.0000 - val_loss: 2.0391 - val_accuracy: 0.7490 - 9s/epoch - 93ms/step
# Epoch 29/100
# 100/100 - 10s - loss: 6.7954e-05 - accuracy: 1.0000 - val_loss: 2.1288 - val_accuracy: 0.7470 - 10s/epoch - 98ms/step
# Epoch 30/100
# 100/100 - 10s - loss: 4.2951e-05 - accuracy: 1.0000 - val_loss: 2.4913 - val_accuracy: 0.7340 - 10s/epoch - 97ms/step
# Epoch 31/100
# 100/100 - 9s - loss: 9.6042e-06 - accuracy: 1.0000 - val_loss: 2.3310 - val_accuracy: 0.7410 - 9s/epoch - 94ms/step
# Epoch 32/100
# 100/100 - 9s - loss: 2.7203e-06 - accuracy: 1.0000 - val_loss: 2.3784 - val_accuracy: 0.7410 - 9s/epoch - 88ms/step
# Epoch 33/100
# 100/100 - 10s - loss: 1.7922e-06 - accuracy: 1.0000 - val_loss: 2.4424 - val_accuracy: 0.7390 - 10s/epoch - 97ms/step
# Epoch 34/100
# 100/100 - 10s - loss: 1.3766e-06 - accuracy: 1.0000 - val_loss: 2.4921 - val_accuracy: 0.7370 - 10s/epoch - 98ms/step
# Epoch 35/100
# 100/100 - 10s - loss: 1.0995e-06 - accuracy: 1.0000 - val_loss: 2.4932 - val_accuracy: 0.7390 - 10s/epoch - 98ms/step
# Epoch 36/100
# 100/100 - 9s - loss: 9.6967e-07 - accuracy: 1.0000 - val_loss: 2.5478 - val_accuracy: 0.7360 - 9s/epoch - 88ms/step
# Epoch 37/100
# 100/100 - 10s - loss: 8.9961e-07 - accuracy: 1.0000 - val_loss: 2.5418 - val_accuracy: 0.7410 - 10s/epoch - 97ms/step
# Epoch 38/100
# 100/100 - 11s - loss: 8.1250e-07 - accuracy: 1.0000 - val_loss: 2.6029 - val_accuracy: 0.7400 - 11s/epoch - 107ms/step
# Epoch 39/100
# 100/100 - 10s - loss: 7.6182e-07 - accuracy: 1.0000 - val_loss: 2.5816 - val_accuracy: 0.7390 - 10s/epoch - 96ms/step
# Epoch 40/100
# 100/100 - 9s - loss: 7.1584e-07 - accuracy: 1.0000 - val_loss: 2.5977 - val_accuracy: 0.7370 - 9s/epoch - 87ms/step
# Epoch 41/100
# 100/100 - 10s - loss: 6.6188e-07 - accuracy: 1.0000 - val_loss: 2.6254 - val_accuracy: 0.7400 - 10s/epoch - 98ms/step
# Epoch 42/100
# 100/100 - 10s - loss: 6.2283e-07 - accuracy: 1.0000 - val_loss: 2.6499 - val_accuracy: 0.7360 - 10s/epoch - 98ms/step
# Epoch 43/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-fc43f60c1de5> in <module>
# ----> 1 history = model.fit(train_generator,
#       2                     validation_data=validation_generator,
#       3                     steps_per_epoch=100,
#       4                     epochs=100,
#       5                     validation_steps=50,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1692                             steps_per_execution=self._steps_per_execution,
#    1693                         )
# -> 1694                     val_logs = self.evaluate(
#    1695                         x=val_x,
#    1696                         y=val_y,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2038                         ):
#    2039                             callbacks.on_test_batch_begin(step)
# -> 2040                             tmp_logs = self.test_function(iterator)
#    2041                             if data_handler.should_sync:
#    2042                                 context.async_wait()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     917       # In this case we have not created variables on the first call. So we can
#     918       # run the first trace but we should fail if variables are created.
# --> 919       results = self._variable_creation_fn(*args, **kwds)
#     920       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     921         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():

  path='/content/' + fn
  img=image.load_img(path, target_size=(150, 150))

  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])

  classes = model.predict(images, batch_size=10)

  print(classes[0])

  if classes[0]>0:
    print(fn + " is a dog")
  else:
    print(fn + " is a cat")
